# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import json
city_data = []

city_url = url + "&q=" + city.replace(" ","+")



city_weather = requests.get(city_url).json()
city_weather
city_weather["weather"][0]["description"]



#disc = city_weather["weather"]["description"]
#print(disc)
# Out:
# 'few clouds'

# %%
city_data = []

city_url = url + "&q=" + city.replace(" ","+")



city_weather = requests.get(city_url).json()

city_lat = city_weather["coord"]["lon"]
city_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_country = city_weather["sys"]["country"]
city_description = city_weather["weather"][0]["description"]

city_data.append({"City": city.title(),
                      "Country": city_country,
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Description": city_description
                     })

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#        City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Belidzhi      RU  48.4125  48.4125     63.25        81          11
#
#    Wind Speed Description
# 0        8.25  few clouds

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lon"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                      "Country": city_country,
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Cloudiness": city_clouds,
                      "Wind Speed": city_wind,
                      "Description": city_description
                     })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao filipe
# Processing Record 2 of Set 1 | cherskiy
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | tartki
# City not found. Skipping...
# Processing Record 6 of Set 1 | aykhal
# Processing Record 7 of Set 1 | panino
# Processing Record 8 of Set 1 | kavaratti
# Processing Record 9 of Set 1 | balakliya
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | flinders
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | cidreira
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | aswan
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | crotone
# Processing Record 19 of Set 1 | marzuq
# Processing Record 20 of Set 1 | candawaga
# City not found. Skipping...
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | narsaq
# Processing Record 25 of Set 1 | ugoofaaru
# Processing Record 26 of Set 1 | xinyang
# Processing Record 27 of Set 1 | codrington
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | cape town
# Processing Record 31 of Set 1 | severo-kurilsk
# Processing Record 32 of Set 1 | saint george
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | egvekinot
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | husavik
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | olafsvik
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | goderich
# Processing Record 43 of Set 1 | lahij
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | palana
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | nemuro
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | viedma
# Processing Record 50 of Set 1 | mount isa
# Processing Record 1 of Set 2 | cabo san lucas
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | bud
# Processing Record 4 of Set 2 | tornio
# Processing Record 5 of Set 2 | martigues
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | lakes entrance
# Processing Record 8 of Set 2 | bajil
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | wajir
# Processing Record 12 of Set 2 | bilibino
# Processing Record 13 of Set 2 | puerto ayora
# Processing Record 14 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 2 | yinchuan
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | noshiro
# Processing Record 18 of Set 2 | arraial do cabo
# Processing Record 19 of Set 2 | ambilobe
# Processing Record 20 of Set 2 | monster
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | rybinsk
# Processing Record 24 of Set 2 | nuevo ideal
# Processing Record 25 of Set 2 | kodiak
# Processing Record 26 of Set 2 | comodoro rivadavia
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | tunceli
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 2 | hobart
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | darab
# Processing Record 37 of Set 2 | yerbogachen
# Processing Record 38 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | rosarito
# Processing Record 44 of Set 2 | ushuaia
# Processing Record 45 of Set 2 | port blair
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | whitianga
# Processing Record 48 of Set 2 | wasilla
# Processing Record 49 of Set 2 | sabang
# Processing Record 50 of Set 2 | saskylakh
# Processing Record 1 of Set 3 | dandong
# Processing Record 2 of Set 3 | chiang khong
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | ban nahin
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 3 | emerald
# Processing Record 8 of Set 3 | coihaique
# Processing Record 9 of Set 3 | tilichiki
# Processing Record 10 of Set 3 | magadan
# Processing Record 11 of Set 3 | kirakira
# Processing Record 12 of Set 3 | erdenet
# Processing Record 13 of Set 3 | jiangyou
# Processing Record 14 of Set 3 | basco
# Processing Record 15 of Set 3 | aljezur
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | canico
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | sinop
# Processing Record 20 of Set 3 | tambura
# Processing Record 21 of Set 3 | vaini
# Processing Record 22 of Set 3 | manokwari
# Processing Record 23 of Set 3 | fairbanks
# Processing Record 24 of Set 3 | vao
# Processing Record 25 of Set 3 | mogadishu
# Processing Record 26 of Set 3 | saint-joseph
# Processing Record 27 of Set 3 | la rioja
# Processing Record 28 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 30 of Set 3 | kalanaur
# Processing Record 31 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 32 of Set 3 | puksoozero
# Processing Record 33 of Set 3 | hohhot
# Processing Record 34 of Set 3 | barra do garcas
# Processing Record 35 of Set 3 | clinton
# Processing Record 36 of Set 3 | vung tau
# Processing Record 37 of Set 3 | yar-sale
# Processing Record 38 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 3 | salta
# Processing Record 40 of Set 3 | tazmalt
# Processing Record 41 of Set 3 | tanjong sepat
# City not found. Skipping...
# Processing Record 42 of Set 3 | samarai
# Processing Record 43 of Set 3 | martapura
# Processing Record 44 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | ust-omchug
# Processing Record 47 of Set 3 | yumen
# Processing Record 48 of Set 3 | tazovskiy
# Processing Record 49 of Set 3 | vallenar
# Processing Record 50 of Set 3 | buta
# Processing Record 1 of Set 4 | aasiaat
# Processing Record 2 of Set 4 | buchanan
# Processing Record 3 of Set 4 | buala
# Processing Record 4 of Set 4 | grand-santi
# Processing Record 5 of Set 4 | ostersund
# Processing Record 6 of Set 4 | tura
# Processing Record 7 of Set 4 | evensk
# Processing Record 8 of Set 4 | champerico
# Processing Record 9 of Set 4 | cukai
# Processing Record 10 of Set 4 | tete
# Processing Record 11 of Set 4 | mangrol
# Processing Record 12 of Set 4 | mitsamiouli
# Processing Record 13 of Set 4 | edea
# Processing Record 14 of Set 4 | ojinaga
# Processing Record 15 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 16 of Set 4 | tuktoyaktuk
# Processing Record 17 of Set 4 | hithadhoo
# Processing Record 18 of Set 4 | pierre
# Processing Record 19 of Set 4 | haines junction
# Processing Record 20 of Set 4 | kahului
# Processing Record 21 of Set 4 | milingimbi
# City not found. Skipping...
# Processing Record 22 of Set 4 | mayor pablo lagerenza
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | sorland
# Processing Record 27 of Set 4 | port augusta
# Processing Record 28 of Set 4 | norman wells
# Processing Record 29 of Set 4 | kruisfontein
# Processing Record 30 of Set 4 | toftir
# City not found. Skipping...
# Processing Record 31 of Set 4 | bataipora
# Processing Record 32 of Set 4 | elizabeth city
# Processing Record 33 of Set 4 | alice springs
# Processing Record 34 of Set 4 | half moon bay
# Processing Record 35 of Set 4 | ngunguru
# Processing Record 36 of Set 4 | prieska
# Processing Record 37 of Set 4 | omutinskoye
# City not found. Skipping...
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | hambantota
# Processing Record 40 of Set 4 | road town
# Processing Record 41 of Set 4 | santa maria
# Processing Record 42 of Set 4 | lavrentiya
# Processing Record 43 of Set 4 | puerto del rosario
# Processing Record 44 of Set 4 | doha
# Processing Record 45 of Set 4 | havelock
# Processing Record 46 of Set 4 | torbay
# Processing Record 47 of Set 4 | general roca
# Processing Record 48 of Set 4 | ibra
# Processing Record 49 of Set 4 | mecca
# Processing Record 50 of Set 4 | kaitangata
# Processing Record 1 of Set 5 | cabedelo
# Processing Record 2 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 5 | necochea
# Processing Record 4 of Set 5 | soyo
# Processing Record 5 of Set 5 | korla
# Processing Record 6 of Set 5 | borodyanka
# Processing Record 7 of Set 5 | nantucket
# Processing Record 8 of Set 5 | kankan
# Processing Record 9 of Set 5 | namatanai
# Processing Record 10 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 11 of Set 5 | zharkent
# Processing Record 12 of Set 5 | padang
# Processing Record 13 of Set 5 | waingapu
# Processing Record 14 of Set 5 | tavrichanka
# Processing Record 15 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 5 | pacific grove
# Processing Record 17 of Set 5 | hami
# Processing Record 18 of Set 5 | okha
# Processing Record 19 of Set 5 | mount gambier
# Processing Record 20 of Set 5 | balabac
# Processing Record 21 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 22 of Set 5 | lasa
# Processing Record 23 of Set 5 | keshan
# City not found. Skipping...
# Processing Record 24 of Set 5 | chapais
# Processing Record 25 of Set 5 | katsuura
# Processing Record 26 of Set 5 | aklavik
# Processing Record 27 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 28 of Set 5 | javanrud
# Processing Record 29 of Set 5 | tessalit
# Processing Record 30 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 5 | zyryanka
# Processing Record 32 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 5 | port macquarie
# Processing Record 34 of Set 5 | srednekolymsk
# Processing Record 35 of Set 5 | vardo
# Processing Record 36 of Set 5 | nara
# Processing Record 37 of Set 5 | rabo de peixe
# Processing Record 38 of Set 5 | hamilton
# Processing Record 39 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 40 of Set 5 | kidal
# Processing Record 41 of Set 5 | alta floresta
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | middle island
# Processing Record 44 of Set 5 | ahipara
# Processing Record 45 of Set 5 | mehran
# Processing Record 46 of Set 5 | port elizabeth
# Processing Record 47 of Set 5 | faanui
# Processing Record 48 of Set 5 | kumbo
# Processing Record 49 of Set 5 | changde
# Processing Record 50 of Set 5 | makung
# City not found. Skipping...
# Processing Record 1 of Set 6 | lipari
# Processing Record 2 of Set 6 | kamaishi
# Processing Record 3 of Set 6 | goundam
# Processing Record 4 of Set 6 | ndola
# Processing Record 5 of Set 6 | buenos aires
# Processing Record 6 of Set 6 | ancud
# Processing Record 7 of Set 6 | borujerd
# Processing Record 8 of Set 6 | belorechensk
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | phalaborwa
# Processing Record 11 of Set 6 | pucallpa
# Processing Record 12 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 13 of Set 6 | itarema
# Processing Record 14 of Set 6 | fort nelson
# Processing Record 15 of Set 6 | ewa beach
# Processing Record 16 of Set 6 | maniitsoq
# Processing Record 17 of Set 6 | cayenne
# Processing Record 18 of Set 6 | leningradskiy
# Processing Record 19 of Set 6 | kalmunai
# Processing Record 20 of Set 6 | garissa
# Processing Record 21 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 6 | aksarka
# Processing Record 24 of Set 6 | xuddur
# Processing Record 25 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 6 | ekhabi
# Processing Record 27 of Set 6 | umm kaddadah
# Processing Record 28 of Set 6 | batagay
# Processing Record 29 of Set 6 | grand baie
# Processing Record 30 of Set 6 | broome
# Processing Record 31 of Set 6 | khromtau
# Processing Record 32 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 6 | muros
# Processing Record 34 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 6 | tautira
# Processing Record 36 of Set 6 | saravan
# Processing Record 37 of Set 6 | gao
# Processing Record 38 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 6 | chadiza
# Processing Record 40 of Set 6 | shimoda
# Processing Record 41 of Set 6 | port lincoln
# Processing Record 42 of Set 6 | nouakchott
# Processing Record 43 of Set 6 | birao
# Processing Record 44 of Set 6 | beloha
# Processing Record 45 of Set 6 | omboue
# Processing Record 46 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 47 of Set 6 | madisonville
# Processing Record 48 of Set 6 | abyek
# Processing Record 49 of Set 6 | marathon
# Processing Record 50 of Set 6 | wagga wagga
# Processing Record 1 of Set 7 | letka
# Processing Record 2 of Set 7 | aitape
# Processing Record 3 of Set 7 | diego de almagro
# Processing Record 4 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 7 | mugur-aksy
# Processing Record 6 of Set 7 | pringsewu
# Processing Record 7 of Set 7 | tifton
# Processing Record 8 of Set 7 | begusarai
# Processing Record 9 of Set 7 | duz
# City not found. Skipping...
# Processing Record 10 of Set 7 | yulara
# Processing Record 11 of Set 7 | houma
# Processing Record 12 of Set 7 | kununurra
# Processing Record 13 of Set 7 | raudeberg
# Processing Record 14 of Set 7 | coruripe
# Processing Record 15 of Set 7 | portland
# Processing Record 16 of Set 7 | mayo
# Processing Record 17 of Set 7 | gamba
# Processing Record 18 of Set 7 | murgab
# Processing Record 19 of Set 7 | salalah
# Processing Record 20 of Set 7 | burica
# City not found. Skipping...
# Processing Record 21 of Set 7 | port moresby
# Processing Record 22 of Set 7 | saldanha
# Processing Record 23 of Set 7 | shitanjing
# Processing Record 24 of Set 7 | qaqortoq
# Processing Record 25 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 7 | kudahuvadhoo
# Processing Record 27 of Set 7 | sosua
# Processing Record 28 of Set 7 | tema
# Processing Record 29 of Set 7 | aripuana
# Processing Record 30 of Set 7 | orlik
# Processing Record 31 of Set 7 | hovd
# Processing Record 32 of Set 7 | avera
# Processing Record 33 of Set 7 | sioux lookout
# Processing Record 34 of Set 7 | crailsheim
# Processing Record 35 of Set 7 | constitucion
# Processing Record 36 of Set 7 | nerchinsk
# Processing Record 37 of Set 7 | akyab
# Processing Record 38 of Set 7 | urusha
# Processing Record 39 of Set 7 | touros
# Processing Record 40 of Set 7 | nayoro
# Processing Record 41 of Set 7 | ferrol
# Processing Record 42 of Set 7 | deputatskiy
# Processing Record 43 of Set 7 | mwingi
# Processing Record 44 of Set 7 | lodja
# Processing Record 45 of Set 7 | susteren
# Processing Record 46 of Set 7 | terme
# Processing Record 47 of Set 7 | peniche
# Processing Record 48 of Set 7 | taltal
# Processing Record 49 of Set 7 | talcahuano
# Processing Record 50 of Set 7 | shakiso
# Processing Record 1 of Set 8 | trowbridge
# Processing Record 2 of Set 8 | faya
# Processing Record 3 of Set 8 | ozernovskiy
# Processing Record 4 of Set 8 | lebu
# Processing Record 5 of Set 8 | petrokamenskoye
# Processing Record 6 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 8 | santa rita
# Processing Record 8 of Set 8 | labuan
# Processing Record 9 of Set 8 | upernavik
# Processing Record 10 of Set 8 | zhigansk
# Processing Record 11 of Set 8 | houston
# Processing Record 12 of Set 8 | bathsheba
# Processing Record 13 of Set 8 | merauke
# Processing Record 14 of Set 8 | chenzhou
# Processing Record 15 of Set 8 | mega
# Processing Record 16 of Set 8 | poronaysk
# Processing Record 17 of Set 8 | amos
# Processing Record 18 of Set 8 | praia
# Processing Record 19 of Set 8 | guerrero negro
# Processing Record 20 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 8 | waipawa
# Processing Record 22 of Set 8 | mustafakemalpasa
# Processing Record 23 of Set 8 | isangel
# Processing Record 24 of Set 8 | shache
# Processing Record 25 of Set 8 | reconquista
# Processing Record 26 of Set 8 | rauma
# Processing Record 27 of Set 8 | izumo
# Processing Record 28 of Set 8 | victoria
# Processing Record 29 of Set 8 | tommot
# Processing Record 30 of Set 8 | ye
# City not found. Skipping...
# Processing Record 31 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 8 | virginia beach
# Processing Record 33 of Set 8 | olinda
# Processing Record 34 of Set 8 | pevek
# Processing Record 35 of Set 8 | carnarvon
# Processing Record 36 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 8 | the valley
# Processing Record 38 of Set 8 | moindou
# Processing Record 39 of Set 8 | port hardy
# Processing Record 40 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 8 | krasnoselkup
# Processing Record 42 of Set 8 | nizwa
# Processing Record 43 of Set 8 | vestmannaeyjar
# Processing Record 44 of Set 8 | sompeta
# Processing Record 45 of Set 8 | fortuna
# Processing Record 46 of Set 8 | kloulklubed
# Processing Record 47 of Set 8 | kurilsk
# Processing Record 48 of Set 8 | anadyr
# Processing Record 49 of Set 8 | longyearbyen
# Processing Record 50 of Set 8 | san francisco
# Processing Record 1 of Set 9 | ghamarwin
# City not found. Skipping...
# Processing Record 2 of Set 9 | ishigaki
# Processing Record 3 of Set 9 | bahia honda
# Processing Record 4 of Set 9 | kenai
# Processing Record 5 of Set 9 | megion
# Processing Record 6 of Set 9 | launceston
# Processing Record 7 of Set 9 | spornoye
# Processing Record 8 of Set 9 | palmas de monte alto
# Processing Record 9 of Set 9 | severnoye
# Processing Record 10 of Set 9 | pangody
# Processing Record 11 of Set 9 | karpenision
# City not found. Skipping...
# Processing Record 12 of Set 9 | komsomolskiy
# Processing Record 13 of Set 9 | saint-augustin
# Processing Record 14 of Set 9 | natal
# Processing Record 15 of Set 9 | tiksi
# Processing Record 16 of Set 9 | los llanos de aridane
# Processing Record 17 of Set 9 | caravelas
# Processing Record 18 of Set 9 | iberia
# Processing Record 19 of Set 9 | harper
# Processing Record 20 of Set 9 | pundaguitan
# Processing Record 21 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | byron bay
# Processing Record 23 of Set 9 | jiayuguan
# Processing Record 24 of Set 9 | manggar
# Processing Record 25 of Set 9 | yantai
# Processing Record 26 of Set 9 | juegang
# Processing Record 27 of Set 9 | lorengau
# Processing Record 28 of Set 9 | san patricio
# Processing Record 29 of Set 9 | nanortalik
# Processing Record 30 of Set 9 | pemba
# Processing Record 31 of Set 9 | bosaso
# Processing Record 32 of Set 9 | kingaroy
# Processing Record 33 of Set 9 | mana
# Processing Record 34 of Set 9 | puerto madero
# Processing Record 35 of Set 9 | grand gaube
# Processing Record 36 of Set 9 | vila velha
# Processing Record 37 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 9 | ostrovnoy
# Processing Record 39 of Set 9 | koppang
# Processing Record 40 of Set 9 | gisborne
# Processing Record 41 of Set 9 | villa carlos paz
# Processing Record 42 of Set 9 | durazno
# Processing Record 43 of Set 9 | umm lajj
# Processing Record 44 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 45 of Set 9 | lima
# Processing Record 46 of Set 9 | chuguyevka
# Processing Record 47 of Set 9 | jaffna
# Processing Record 48 of Set 9 | sao lourenco do oeste
# Processing Record 49 of Set 9 | newala
# Processing Record 50 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 10 | sao felix do xingu
# Processing Record 2 of Set 10 | ahuimanu
# Processing Record 3 of Set 10 | bambanglipuro
# Processing Record 4 of Set 10 | mbala
# Processing Record 5 of Set 10 | tuatapere
# Processing Record 6 of Set 10 | kavieng
# Processing Record 7 of Set 10 | falaleu
# City not found. Skipping...
# Processing Record 8 of Set 10 | linapacan
# City not found. Skipping...
# Processing Record 9 of Set 10 | keflavik
# Processing Record 10 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 10 | iquitos
# Processing Record 12 of Set 10 | jirlau
# Processing Record 13 of Set 10 | yantzaza
# Processing Record 14 of Set 10 | alugan
# Processing Record 15 of Set 10 | college
# Processing Record 16 of Set 10 | rudsar
# Processing Record 17 of Set 10 | uray
# Processing Record 18 of Set 10 | honiara
# Processing Record 19 of Set 10 | maningrida
# Processing Record 20 of Set 10 | pteleos
# Processing Record 21 of Set 10 | ust-kuyga
# Processing Record 22 of Set 10 | acapulco
# Processing Record 23 of Set 10 | fare
# Processing Record 24 of Set 10 | san andres
# Processing Record 25 of Set 10 | manta
# Processing Record 26 of Set 10 | gornyy
# Processing Record 27 of Set 10 | yeppoon
# Processing Record 28 of Set 10 | tharrawaddy
# City not found. Skipping...
# Processing Record 29 of Set 10 | grindavik
# Processing Record 30 of Set 10 | malindi
# Processing Record 31 of Set 10 | sulphur
# Processing Record 32 of Set 10 | klyuchi
# Processing Record 33 of Set 10 | khalkhal
# Processing Record 34 of Set 10 | nevers
# Processing Record 35 of Set 10 | moose factory
# Processing Record 36 of Set 10 | sitka
# Processing Record 37 of Set 10 | kristiansund
# Processing Record 38 of Set 10 | port hedland
# Processing Record 39 of Set 10 | binga
# Processing Record 40 of Set 10 | oroshaza
# Processing Record 41 of Set 10 | nador
# Processing Record 42 of Set 10 | ketchikan
# Processing Record 43 of Set 10 | novo aripuana
# Processing Record 44 of Set 10 | mercedes
# Processing Record 45 of Set 10 | westport
# Processing Record 46 of Set 10 | salgueiro
# Processing Record 47 of Set 10 | hualmay
# Processing Record 48 of Set 10 | mehamn
# Processing Record 49 of Set 10 | manono
# Processing Record 50 of Set 10 | clyde river
# Processing Record 1 of Set 11 | ternate
# Processing Record 2 of Set 11 | sur
# Processing Record 3 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 11 | hunchun
# Processing Record 5 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 11 | winder
# Processing Record 7 of Set 11 | nosy varika
# Processing Record 8 of Set 11 | buluang
# Processing Record 9 of Set 11 | gladstone
# Processing Record 10 of Set 11 | rio grande
# Processing Record 11 of Set 11 | russell
# Processing Record 12 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 13 of Set 11 | saskatoon
# Processing Record 14 of Set 11 | qui nhon
# Processing Record 15 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 11 | seydi
# Processing Record 17 of Set 11 | duldurga
# Processing Record 18 of Set 11 | shenjiamen
# Processing Record 19 of Set 11 | burkhala
# City not found. Skipping...
# Processing Record 20 of Set 11 | billings
# Processing Record 21 of Set 11 | urumqi
# Processing Record 22 of Set 11 | bhanjanagar
# Processing Record 23 of Set 11 | sri aman
# Processing Record 24 of Set 11 | swan river
# Processing Record 25 of Set 11 | puerto escondido
# Processing Record 26 of Set 11 | liwale
# Processing Record 27 of Set 11 | maicao
# Processing Record 28 of Set 11 | kariba
# Processing Record 29 of Set 11 | mbini
# Processing Record 30 of Set 11 | balykshi
# Processing Record 31 of Set 11 | kupang
# Processing Record 32 of Set 11 | xuanhua
# Processing Record 33 of Set 11 | chibuto
# Processing Record 34 of Set 11 | kathu
# Processing Record 35 of Set 11 | veraval
# Processing Record 36 of Set 11 | novosil
# Processing Record 37 of Set 11 | monroe
# Processing Record 38 of Set 11 | tual
# Processing Record 39 of Set 11 | florin
# Processing Record 40 of Set 11 | aleksandrov gay
# Processing Record 41 of Set 11 | uige
# Processing Record 42 of Set 11 | silver city
# Processing Record 43 of Set 11 | mirpur sakro
# Processing Record 44 of Set 11 | batagay-alyta
# Processing Record 45 of Set 11 | riverton
# Processing Record 46 of Set 11 | evanton
# Processing Record 47 of Set 11 | thakurgaon
# Processing Record 48 of Set 11 | sao paulo de olivenca
# Processing Record 49 of Set 11 | yithion
# City not found. Skipping...
# Processing Record 50 of Set 11 | tecoanapa
# Processing Record 1 of Set 12 | san martin
# Processing Record 2 of Set 12 | sayanskiy
# City not found. Skipping...
# Processing Record 3 of Set 12 | sola
# Processing Record 4 of Set 12 | kaohsiung
# Processing Record 5 of Set 12 | ixtapa
# Processing Record 6 of Set 12 | gariadhar
# Processing Record 7 of Set 12 | piranhas
# Processing Record 8 of Set 12 | mao
# Processing Record 9 of Set 12 | daru
# Processing Record 10 of Set 12 | turayf
# Processing Record 11 of Set 12 | luanda
# Processing Record 12 of Set 12 | alofi
# Processing Record 13 of Set 12 | nuevo laredo
# Processing Record 14 of Set 12 | itoman
# Processing Record 15 of Set 12 | khandbari
# Processing Record 16 of Set 12 | saint-pierre
# Processing Record 17 of Set 12 | maple creek
# Processing Record 18 of Set 12 | chita
# Processing Record 19 of Set 12 | kolosovka
# Processing Record 20 of Set 12 | port-cartier
# Processing Record 21 of Set 12 | bairiki
# Processing Record 22 of Set 12 | siutu
# City not found. Skipping...
# Processing Record 23 of Set 12 | kieta
# Processing Record 24 of Set 12 | avanigadda
# Processing Record 25 of Set 12 | sao tome
# Processing Record 26 of Set 12 | grand-lahou
# Processing Record 27 of Set 12 | dulag
# Processing Record 28 of Set 12 | porto-vecchio
# Processing Record 29 of Set 12 | oktyabrskoye
# Processing Record 30 of Set 12 | miyako
# Processing Record 31 of Set 12 | iqaluit
# Processing Record 32 of Set 12 | rawson
# Processing Record 33 of Set 12 | morada nova
# Processing Record 34 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 12 | tome-acu
# City not found. Skipping...
# Processing Record 36 of Set 12 | margate
# Processing Record 37 of Set 12 | trincomalee
# Processing Record 38 of Set 12 | rincon
# Processing Record 39 of Set 12 | saint-raphael
# Processing Record 40 of Set 12 | bam
# Processing Record 41 of Set 12 | vangaindrano
# Processing Record 42 of Set 12 | paita
# Processing Record 43 of Set 12 | waddan
# Processing Record 44 of Set 12 | moussoro
# Processing Record 45 of Set 12 | gudari
# Processing Record 46 of Set 12 | nuuk
# Processing Record 47 of Set 12 | jumla
# Processing Record 48 of Set 12 | lake city
# Processing Record 49 of Set 12 | oshakati
# Processing Record 50 of Set 12 | vanavara
# Processing Record 1 of Set 13 | wainwright
# Processing Record 2 of Set 13 | miharu
# Processing Record 3 of Set 13 | pointe michel
# Processing Record 4 of Set 13 | la ronge
# Processing Record 5 of Set 13 | bubaque
# Processing Record 6 of Set 13 | bull savanna
# Processing Record 7 of Set 13 | laguna
# Processing Record 8 of Set 13 | kabare
# Processing Record 9 of Set 13 | tchollire
# Processing Record 10 of Set 13 | powell
# Processing Record 11 of Set 13 | vanimo
# Processing Record 12 of Set 13 | barra patuca
# Processing Record 13 of Set 13 | acarau
# Processing Record 14 of Set 13 | lamu
# Processing Record 15 of Set 13 | inta
# Processing Record 16 of Set 13 | pirgos
# Processing Record 17 of Set 13 | shubarshi
# Processing Record 18 of Set 13 | luena
# Processing Record 19 of Set 13 | manacor
# Processing Record 20 of Set 13 | ola
# Processing Record 21 of Set 13 | palmer
# Processing Record 22 of Set 13 | borne
# Processing Record 23 of Set 13 | bonthe
# Processing Record 24 of Set 13 | salantai
# Processing Record 25 of Set 13 | lompoc
# Processing Record 26 of Set 13 | jacqueville
# Processing Record 27 of Set 13 | maamba
# Processing Record 28 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 29 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 13 | naze
# Processing Record 31 of Set 13 | yingzhong
# City not found. Skipping...
# Processing Record 32 of Set 13 | dongsheng
# Processing Record 33 of Set 13 | inhambane
# Processing Record 34 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 13 | itanhandu
# Processing Record 36 of Set 13 | pisco
# Processing Record 37 of Set 13 | dindori
# Processing Record 38 of Set 13 | isugod
# Processing Record 39 of Set 13 | malangali
# Processing Record 40 of Set 13 | likasi
# Processing Record 41 of Set 13 | mendahara
# City not found. Skipping...
# Processing Record 42 of Set 13 | grand forks
# Processing Record 43 of Set 13 | lagoa
# Processing Record 44 of Set 13 | matara
# Processing Record 45 of Set 13 | tucurui
# Processing Record 46 of Set 13 | san carlos de bariloche
# Processing Record 47 of Set 13 | meulaboh
# Processing Record 48 of Set 13 | ribeira brava
# Processing Record 49 of Set 13 | amahai
# Processing Record 50 of Set 13 | lockport
# Processing Record 1 of Set 14 | opole lubelskie
# Processing Record 2 of Set 14 | shwebo
# Processing Record 3 of Set 14 | roma
# Processing Record 4 of Set 14 | porto walter
# Processing Record 5 of Set 14 | belle fourche
# Processing Record 6 of Set 14 | mpongwe
# Processing Record 7 of Set 14 | pahrump
# Processing Record 8 of Set 14 | praia da vitoria
# Processing Record 9 of Set 14 | santa rosa
# Processing Record 10 of Set 14 | santa isabel do rio negro
# Processing Record 11 of Set 14 | pennadam
# Processing Record 12 of Set 14 | ibotirama
# Processing Record 13 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 14 | challapata
# Processing Record 15 of Set 14 | sao joao da barra
# Processing Record 16 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 14 | kysyl-syr
# Processing Record 18 of Set 14 | vila franca do campo
# Processing Record 19 of Set 14 | quatre cocos
# Processing Record 20 of Set 14 | agbor
# Processing Record 21 of Set 14 | solnechnyy
# Processing Record 22 of Set 14 | caninde de sao francisco
# Processing Record 23 of Set 14 | hokitika
# Processing Record 24 of Set 14 | san quintin
# Processing Record 25 of Set 14 | kattivakkam
# Processing Record 26 of Set 14 | bom jardim
# Processing Record 27 of Set 14 | udachnyy
# Processing Record 28 of Set 14 | nieuw amsterdam
# Processing Record 29 of Set 14 | maldonado
# Processing Record 30 of Set 14 | yichun
# Processing Record 31 of Set 14 | godo
# Processing Record 32 of Set 14 | patitirion
# Processing Record 33 of Set 14 | balsas
# Processing Record 34 of Set 14 | baykit
# Processing Record 35 of Set 14 | amapa
# Processing Record 36 of Set 14 | jining
# Processing Record 37 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 38 of Set 14 | xining
# Processing Record 39 of Set 14 | bilma
# Processing Record 40 of Set 14 | ulladulla
# Processing Record 41 of Set 14 | palauig
# Processing Record 42 of Set 14 | mangai
# Processing Record 43 of Set 14 | vostok
# Processing Record 44 of Set 14 | poya
# Processing Record 45 of Set 14 | balikpapan
# Processing Record 46 of Set 14 | kharp
# Processing Record 47 of Set 14 | okhotsk
# Processing Record 48 of Set 14 | high level
# Processing Record 49 of Set 14 | mount pleasant
# Processing Record 50 of Set 14 | biak
# Processing Record 1 of Set 15 | maragogi
# Processing Record 2 of Set 15 | porto novo
# Processing Record 3 of Set 15 | gigmoto
# Processing Record 4 of Set 15 | micheweni
# Processing Record 5 of Set 15 | pleshanovo
# Processing Record 6 of Set 15 | taoudenni
# Processing Record 7 of Set 15 | kyren
# Processing Record 8 of Set 15 | orshanka
# Processing Record 9 of Set 15 | maceio
# Processing Record 10 of Set 15 | sassandra
# Processing Record 11 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 15 | concarneau
# Processing Record 13 of Set 15 | giyon
# Processing Record 14 of Set 15 | turtkul
# City not found. Skipping...
# Processing Record 15 of Set 15 | sao domingos
# Processing Record 16 of Set 15 | te anau
# Processing Record 17 of Set 15 | sapa
# Processing Record 18 of Set 15 | boende
# Processing Record 19 of Set 15 | thai binh
# Processing Record 20 of Set 15 | preobrazheniye
# Processing Record 21 of Set 15 | neiafu
# Processing Record 22 of Set 15 | erenhot
# Processing Record 23 of Set 15 | sterling
# Processing Record 24 of Set 15 | alamo
# Processing Record 25 of Set 15 | capanema
# Processing Record 26 of Set 15 | esik
# Processing Record 27 of Set 15 | verkhoyansk
# Processing Record 28 of Set 15 | dilla
# Processing Record 29 of Set 15 | atambua
# Processing Record 30 of Set 15 | malibu
# Processing Record 31 of Set 15 | lodwar
# Processing Record 32 of Set 15 | barentu
# Processing Record 33 of Set 15 | karatau
# Processing Record 34 of Set 15 | les cayes
# Processing Record 35 of Set 15 | vicuna
# Processing Record 36 of Set 15 | shingu
# Processing Record 37 of Set 15 | sambava
# Processing Record 38 of Set 15 | roebourne
# Processing Record 39 of Set 15 | kusk
# City not found. Skipping...
# Processing Record 40 of Set 15 | pala
# Processing Record 41 of Set 15 | zhob
# Processing Record 42 of Set 15 | linjiang
# Processing Record 43 of Set 15 | brandys nad labem-stara boleslav
# Processing Record 44 of Set 15 | murwillumbah
# Processing Record 45 of Set 15 | almora
# Processing Record 46 of Set 15 | markova
# Processing Record 47 of Set 15 | adrar
# Processing Record 48 of Set 15 | cockburn town
# Processing Record 49 of Set 15 | whitehorse
# Processing Record 50 of Set 15 | jacksonville beach
# Processing Record 1 of Set 16 | khasan
# Processing Record 2 of Set 16 | weiser
# Processing Record 3 of Set 16 | novoagansk
# Processing Record 4 of Set 16 | perbaungan
# Processing Record 5 of Set 16 | roswell
# Processing Record 6 of Set 16 | dalvik
# Processing Record 7 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 16 | volodarka
# Processing Record 9 of Set 16 | horsham
# Processing Record 10 of Set 16 | cam pha
# City not found. Skipping...
# Processing Record 11 of Set 16 | qesarya
# Processing Record 12 of Set 16 | abu jubayhah
# City not found. Skipping...
# Processing Record 13 of Set 16 | panshi
# Processing Record 14 of Set 16 | nortelandia
# Processing Record 15 of Set 16 | lata
# Processing Record 16 of Set 16 | huilong
# Processing Record 17 of Set 16 | staryy saltiv
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country       Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Sao Filipe      CV  -24.4956  -24.4956     73.76        77          18
# 1     Cherskiy      RU  161.3000  161.3000     70.21        33          80
# 2  Port Alfred      ZA   26.8910   26.8910     62.47        36           0
# 3       Aykhal      RU  111.5000  111.5000     40.21        90          53
# 4       Panino      RU   40.1346   40.1346     55.17        96          24
# 5    Kavaratti      IN   72.6420   72.6420     82.17        78         100
# 6    Balakliya      UA   36.8595   36.8595     58.03        95           4
# 7         Hilo      US -155.0900 -155.0900     83.28        71          90
# 8     Flinders      AU  150.8552  150.8552     67.37        60          99
# 9   Nikolskoye      RU   30.7861   30.7861     57.09        87          98
#
#    Wind Speed      Description
# 0        8.59       few clouds
# 1       20.40    broken clouds
# 2        9.46        clear sky
# 3       27.94       light rain
# 4        5.70       few clouds
# 5       12.91  overcast clouds
# 6        4.99        clear sky
# 7       13.80  overcast clouds
# 8        1.99  overcast clouds
# 9        3.38  overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/W.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
